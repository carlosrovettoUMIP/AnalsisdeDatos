# %% [markdown]
# # ⚓ Módulo 7: Reto Integrador
# ### Maestría en Logística y Transporte Marítimo — UMIP
# #### Preparado por: Jcenteno
#
# Consolidación de competencias mediante un proyecto de análisis de extremo a extremo.
#
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_palette("magma")
print("✅ Framework integrador cargado")

# %% [markdown]
# ## 1. Análisis Exploratorio del Corredor Atlántico-Pacífico
# Este dataset multivariable incluye tráfico, tiempos, costos y condiciones climáticas.

# %%
# Simulación de datos del corredor
np.random.seed(99)
corredor = pd.DataFrame({
    'transito_id': range(1001, 1501),
    'tiempo_horas': np.random.uniform(8, 24, 500),
    'teus': np.random.randint(500, 18000, 500),
    'costo_millon_usd': np.random.uniform(0.1, 1.2, 500),
    'precipitacion_mm': np.random.uniform(10, 100, 500)
})

sns.jointplot(data=corredor, x="teus", y="tiempo_horas", kind="hex", color="#4CB391")
plt.show()

# %% [markdown]
# ## 2. Desarrollo del Informe Ejecutivo
# Estructura tu análisis basándote en los hallazgos anteriores.

# %%
print("📋 ESTRUCTURA RECOMENDADA:")
print("1. Resumen: Mensajes clave del corredor.")
print("2. Hallazgo: ¿Cómo afecta el clima al tiempo de tránsito?")
print("3. Financiero: Eficiencia de costo por contenedor procesado.")
print("4. Recomendación accionable para la Junta Directiva.")

# %% [markdown]
# ## 🚀 Laboratorio M7
# **Entregable**: Crea un informe de 2 páginas con visualizaciones que soporte una inversión en sistemas de gestión de clima para reducir el tiempo de espera en el corredor.
